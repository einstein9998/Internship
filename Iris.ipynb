# %%
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
#separate features
sepal_length = iris.data[:, 0]
sepal_width = iris.data[:, 1]
petal_length = iris.data[:, 2]
petal_width = iris.data[:, 3]
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
from matplotlib import pyplot as plt

# %%
#visualize the data for each feature
plt.figure()
plt.boxplot([sepal_length, sepal_width, petal_length, petal_width])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f42bc131c88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f42bc1396d8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f42bc142390>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f42bc139f28>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f42bc131dd8>,
# ...
#   <matplotlib.lines.Line2D at 0x7f42bc0e4b38>]}

# %%
from sklearn.neighbors import NearestNeighbors

# %%
#add a target column so that the type of iris is preserved when the data is randomized
target = iris.target[..., None]
targetAndData = np.append(target, iris.data, 1)
# Out:
# array([[0. , 5.1, 3.5, 1.4, 0.2],
#        [0. , 4.9, 3. , 1.4, 0.2],
#        [0. , 4.7, 3.2, 1.3, 0.2],
#        [0. , 4.6, 3.1, 1.5, 0.2],
#        [0. , 5. , 3.6, 1.4, 0.2],
#        [0. , 5.4, 3.9, 1.7, 0.4],
#        [0. , 4.6, 3.4, 1.4, 0.3],
#        [0. , 5. , 3.4, 1.5, 0.2],
#        [0. , 4.4, 2.9, 1.4, 0.2],
#        [0. , 4.9, 3.1, 1.5, 0.1],
#        [0. , 5.4, 3.7, 1.5, 0.2],
#        [0. , 4.8, 3.4, 1.6, 0.2],
#        [0. , 4.8, 3. , 1.4, 0.1],
#        [0. , 4.3, 3. , 1.1, 0.1],
#        [0. , 5.8, 4. , 1.2, 0.2],
#        [0. , 5.7, 4.4, 1.5, 0.4],
#        [0. , 5.4, 3.9, 1.3, 0.4],
#        [0. , 5.1, 3.5, 1.4, 0.3],
#        [0. , 5.7, 3.8, 1.7, 0.3],
#        [0. , 5.1, 3.8, 1.5, 0.3],
#        [0. , 5.4, 3.4, 1.7, 0.2],
#        [0. , 5.1, 3.7, 1.5, 0.4],
#        [0. , 4.6, 3.6, 1. , 0.2],
#        [0. , 5.1, 3.3, 1.7, 0.5],
#        [0. , 4.8, 3.4, 1.9, 0.2],
#        [0. , 5. , 3. , 1.6, 0.2],
#        [0. , 5. , 3.4, 1.6, 0.4],
# ...

# %%
# Out:
# array([[0.00e+00, 5.10e+00, 3.50e+00, 1.40e+00, 2.00e-01],
#        [1.00e+00, 4.90e+00, 3.00e+00, 1.40e+00, 2.00e-01],
#        [2.00e+00, 4.70e+00, 3.20e+00, 1.30e+00, 2.00e-01],
#        [3.00e+00, 4.60e+00, 3.10e+00, 1.50e+00, 2.00e-01],
#        [4.00e+00, 5.00e+00, 3.60e+00, 1.40e+00, 2.00e-01],
#        [5.00e+00, 5.40e+00, 3.90e+00, 1.70e+00, 4.00e-01],
#        [6.00e+00, 4.60e+00, 3.40e+00, 1.40e+00, 3.00e-01],
#        [7.00e+00, 5.00e+00, 3.40e+00, 1.50e+00, 2.00e-01],
#        [8.00e+00, 4.40e+00, 2.90e+00, 1.40e+00, 2.00e-01],
#        [9.00e+00, 4.90e+00, 3.10e+00, 1.50e+00, 1.00e-01],
#        [1.00e+01, 5.40e+00, 3.70e+00, 1.50e+00, 2.00e-01],
#        [1.10e+01, 4.80e+00, 3.40e+00, 1.60e+00, 2.00e-01],
#        [1.20e+01, 4.80e+00, 3.00e+00, 1.40e+00, 1.00e-01],
#        [1.30e+01, 4.30e+00, 3.00e+00, 1.10e+00, 1.00e-01],
#        [1.40e+01, 5.80e+00, 4.00e+00, 1.20e+00, 2.00e-01],
#        [1.50e+01, 5.70e+00, 4.40e+00, 1.50e+00, 4.00e-01],
# ...

# %%
#choose 70% of the indices for the training group, and the remaining 30% for the test group
np.random.seed(1435)
a = np.arange(len(data))
np.random.shuffle(a)
trainingDataIndices = a[:105]
queryDataIndices = a[105:]

# %%
targetAndData
# Out:
# array([[0. , 5.1, 3.5, 1.4, 0.2],
#        [0. , 4.9, 3. , 1.4, 0.2],
#        [0. , 4.7, 3.2, 1.3, 0.2],
#        [0. , 4.6, 3.1, 1.5, 0.2],
#        [0. , 5. , 3.6, 1.4, 0.2],
#        [0. , 5.4, 3.9, 1.7, 0.4],
#        [0. , 4.6, 3.4, 1.4, 0.3],
#        [0. , 5. , 3.4, 1.5, 0.2],
#        [0. , 4.4, 2.9, 1.4, 0.2],
#        [0. , 4.9, 3.1, 1.5, 0.1],
#        [0. , 5.4, 3.7, 1.5, 0.2],
#        [0. , 4.8, 3.4, 1.6, 0.2],
#        [0. , 4.8, 3. , 1.4, 0.1],
#        [0. , 4.3, 3. , 1.1, 0.1],
#        [0. , 5.8, 4. , 1.2, 0.2],
#        [0. , 5.7, 4.4, 1.5, 0.4],
#        [0. , 5.4, 3.9, 1.3, 0.4],
#        [0. , 5.1, 3.5, 1.4, 0.3],
#        [0. , 5.7, 3.8, 1.7, 0.3],
#        [0. , 5.1, 3.8, 1.5, 0.3],
#        [0. , 5.4, 3.4, 1.7, 0.2],
#        [0. , 5.1, 3.7, 1.5, 0.4],
#        [0. , 4.6, 3.6, 1. , 0.2],
#        [0. , 5.1, 3.3, 1.7, 0.5],
#        [0. , 4.8, 3.4, 1.9, 0.2],
#        [0. , 5. , 3. , 1.6, 0.2],
#        [0. , 5. , 3.4, 1.6, 0.4],
# ...

# %%
#build the data sets from the master set
trainingDataWithTarget = targetAndData[trainingDataIndices, :]
queryDataWithTarget = targetAndData[queryDataIndices, :]

#cut off the target column
trainingData = trainingDataWithTarget[:, range(1, 5)]
queryData = queryDataWithTarget[:, range(1, 5)]

# %%
trainingDataWithTarget
# Out:
# array([[2. , 7.2, 3. , 5.8, 1.6],
#        [0. , 4.3, 3. , 1.1, 0.1],
#        [2. , 6.2, 3.4, 5.4, 2.3],
#        [2. , 5.7, 2.5, 5. , 2. ],
#        [2. , 6.4, 2.8, 5.6, 2.1],
#        [1. , 5.1, 2.5, 3. , 1.1],
#        [1. , 5.8, 2.7, 3.9, 1.2],
#        [0. , 5.4, 3.7, 1.5, 0.2],
#        [0. , 5.7, 3.8, 1.7, 0.3],
#        [2. , 6.3, 2.5, 5. , 1.9],
#        [2. , 6.5, 3.2, 5.1, 2. ],
#        [1. , 6.7, 3.1, 4.7, 1.5],
#        [1. , 5.7, 2.8, 4.5, 1.3],
#        [2. , 6.3, 2.7, 4.9, 1.8],
#        [0. , 5. , 3.6, 1.4, 0.2],
#        [1. , 6.2, 2.9, 4.3, 1.3],
#        [0. , 4.9, 3.1, 1.5, 0.1],
#        [0. , 5.8, 4. , 1.2, 0.2],
#        [0. , 4.8, 3. , 1.4, 0.3],
#        [1. , 5.8, 2.7, 4.1, 1. ],
#        [1. , 4.9, 2.4, 3.3, 1. ],
#        [1. , 6.1, 2.8, 4. , 1.3],
#        [2. , 6.7, 3.3, 5.7, 2.1],
#        [1. , 6. , 2.7, 5.1, 1.6],
#        [2. , 6.1, 3. , 4.9, 1.8],
#        [0. , 5.5, 3.5, 1.3, 0.2],
#        [0. , 5. , 3.3, 1.4, 0.2],
# ...

# %%
#create a nerest neighbors model trained on the training data
m = NearestNeighbors(n_neighbors=15)
m.fit(trainingData)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=15, p=2, radius=1.0)

# %%
#pass in the queries
distances, indices = m.kneighbors(queryData)

#Query number, Query label, Closest neighbor's label, Closest distance
ret = [[i, int(queryDataWithTarget[i][0]),  int(trainingDataWithTarget[indices[:, 0][i]][0]) ,distances[:, 0][i]] for i in range(len(indices[:, 0]))]

print("Success Rate: " + str(sum(ret[i][1] == ret[i][2] for i in range(len(ret)))/len(ret) * 100) + "%")
ret
# Out:
# Success Rate: 97.77777777777777%
# [[0, 2, 2, 0.6324555320336759],
#  [1, 1, 1, 0.26457513110645864],
#  [2, 1, 2, 0.22360679774997896],
#  [3, 2, 2, 0.282842712474618],
#  [4, 2, 2, 0.5477225575051662],
#  [5, 2, 2, 0.26457513110645936],
#  [6, 0, 0, 0.22360679774997877],
#  [7, 1, 1, 0.2645751311064593],
#  [8, 0, 0, 0.3464101615137755],
#  [9, 1, 1, 0.3741657386773941],
#  [10, 2, 2, 0.26457513110645897],
#  [11, 0, 0, 0.14142135623730964],
#  [12, 0, 0, 0.14142135623730964],
#  [13, 2, 2, 0.24494897427831785],
#  [14, 0, 0, 0.7141428428542852],
#  [15, 0, 0, 0.3605551275463992],
#  [16, 2, 2, 0.26457513110645897],
#  [17, 0, 0, 0.22360679774997896],
#  [18, 2, 2, 0.34641016151377513],
#  [19, 0, 0, 0.2999999999999998],
#  [20, 1, 1, 0.24494897427831785],
#  [21, 1, 1, 0.43588989435406744],
#  [22, 2, 2, 0.3464101615137756],
#  [23, 1, 1, 0.2645751311064588],
#  [24, 1, 1, 0.14142135623730995],
#  [25, 0, 0, 0.45825756949558394],
#  [26, 1, 1, 0.14142135623730995],
# ...

# %%
def nearestNeighborsTest(dataSet, targets, trainingSplit, n_neighbors):
    size = len(dataSet)
    num_features = len(dataSet[0])
    
    #add a target column so that the type of iris is preserved when the data is randomized
    targetAndData = np.append(targets[..., None], dataSet, 1)
    
    #choose some of the indices for the training group, and the remaining for the test group
    np.random.seed(1435)
    a = np.arange(size)
    np.random.shuffle(a)
    split = int(trainingSplit * size)
    trainingDataIndices = a[:split]
    queryDataIndices = a[split:]
    
    #build the data sets from the master set
    trainingDataWithTarget = targetAndData[trainingDataIndices, :]
    queryDataWithTarget = targetAndData[queryDataIndices, :]
    
    #cut off the target column
    trainingData = trainingDataWithTarget[:, range(1, num_features + 1)]
    queryData = queryDataWithTarget[:, range(1, num_features + 1)]
    
    #create a nerest neighbors model trained on the training data
    m = NearestNeighbors(n_neighbors=n_neighbors)
    m.fit(trainingData)
    
    #pass in the queries
    distances, indices = m.kneighbors(queryData)

    #Query number, Query label, Closest neighbor's label, Closest distance
    ret = [[i, int(queryDataWithTarget[i][0]),  int(trainingDataWithTarget[indices[:, 0][i]][0]) ,distances[:, 0][i]] for i in range(len(indices[:, 0]))]

    success_rate = sum(ret[i][1] == ret[i][2] for i in range(len(ret)))/len(ret)
    
   #print("Success Rate: " + str(success_rate * 100) + "%")
    
    
    return ret, success_rate

# %%
nearestNeighborsTest(iris.data, iris.target, 0.7, 15)
# Out:
# Success Rate: 97.77777777777777%
# ([[0, 2, 2, 0.6324555320336759],
#   [1, 1, 1, 0.26457513110645864],
#   [2, 1, 2, 0.22360679774997896],
#   [3, 2, 2, 0.282842712474618],
#   [4, 2, 2, 0.5477225575051662],
#   [5, 2, 2, 0.26457513110645936],
#   [6, 0, 0, 0.22360679774997877],
#   [7, 1, 1, 0.2645751311064593],
#   [8, 0, 0, 0.3464101615137755],
#   [9, 1, 1, 0.3741657386773941],
#   [10, 2, 2, 0.26457513110645897],
#   [11, 0, 0, 0.14142135623730964],
#   [12, 0, 0, 0.14142135623730964],
#   [13, 2, 2, 0.24494897427831785],
#   [14, 0, 0, 0.7141428428542852],
#   [15, 0, 0, 0.3605551275463992],
#   [16, 2, 2, 0.26457513110645897],
#   [17, 0, 0, 0.22360679774997896],
#   [18, 2, 2, 0.34641016151377513],
#   [19, 0, 0, 0.2999999999999998],
#   [20, 1, 1, 0.24494897427831785],
#   [21, 1, 1, 0.43588989435406744],
#   [22, 2, 2, 0.3464101615137756],
#   [23, 1, 1, 0.2645751311064588],
#   [24, 1, 1, 0.14142135623730995],
#   [25, 0, 0, 0.45825756949558394],
# ...

# %%
x = []
y = []
for split in np.arange(0.1, 1.0, 0.1):
    _, success = nearestNeighborsTest(iris.data, iris.target, split, 15)
    x.append(split)
    y.append(success)
    
plt.figure(1)
plt.xlabel("Proportion of Data Used to Train")
plt.ylabel("Classification Success Rate")
plt.scatter(x, y)
plt.show()
